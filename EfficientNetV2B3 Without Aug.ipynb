# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import tensorflow as tf
import time
# from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetV2B3
from tensorflow.keras.applications.efficientnet_v2 import preprocess_input
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
# from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2

# %%
train_dir = "C:\\Users\\asusm\\Dropbox\\PC\\Downloads\\TA\\dataset"
validation_dir = "C:\\Users\\asusm\\Dropbox\\PC\\Downloads\\TA\\Split\\validasi"

# %%
# Tanpa augmentasi, hanya preprocessing dari EfficientNetV2B3
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
# Load data pelatihan
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 163 images belonging to 12 classes.

# %%
# ImageDataGenerator untuk data validasi (tanpa augmentasi)
val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

# Load data validasi
validation_generator = val_datagen.flow_from_directory(
    validation_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 720 images belonging to 12 classes.

# %%
# # Nama kelas
# classes = ['Nose', 'Nose Disease']

# # Plot untuk menampilkan hasil
# plt.figure(figsize=(12, 18))

# for idx, class_name in enumerate(classes):
#     # Ambil satu gambar dari setiap kelas
#     class_dir = os.path.join(train_dir, class_name)
#     image_path = os.path.join(class_dir, os.listdir(class_dir)[0])  # Gambar pertama di kelas tersebut
    
#     # Load gambar
#     original_image = load_img(image_path)  # PIL image
#     original_image_array = img_to_array(original_image)  # Numpy array
#     original_image_array = original_image_array[np.newaxis, ...]  # Tambahkan batch dimension
    
#     # Generator augmentasi
#     augmented_images = train_datagen.flow(original_image_array, batch_size=1)
#     augmented_image = next(augmented_images)[0]  # Hasil augmentasi pertama
    
#     # Tampilkan gambar asli
#     plt.subplot(6, 2, idx * 2 + 1)
#     plt.imshow(original_image)
#     plt.title(f"Original: {class_name}")
#     plt.axis("off")
    
#     # Tampilkan hasil augmentasi
#     plt.subplot(6, 2, idx * 2 + 2)
#     plt.imshow(augmented_image)
#     plt.title(f"Augmented: {class_name}")
#     plt.axis("off")

# plt.tight_layout()
# plt.show()

# %%
# Load EfficientNetV2B0
base_model = EfficientNetV2B3(include_top=False, input_shape=(224, 224, 3), weights='imagenet')

base_model.trainable = False

model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(256, activation="relu", kernel_regularizer=l2(0.0005)),  # Perbesar regularisasi
    BatchNormalization(),
    Dropout(0.3),  # Perbesar dropout
    Dense(128, activation="relu", kernel_regularizer=l2(0.0005)),  # Perbesar regularisasi
    BatchNormalization(),
    Dropout(0.3),  # Perbesar dropout
    Dense(12, activation="softmax")
])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ efficientnetv2-b3 (Functional)  │ (None, 7, 7, 1536)     │    12,930,622 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1536)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       393,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 12)             │         1,548 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,360,074 (50.96 MB)
#  Trainable params: 428,684 (1.64 MB)
#  Non-trainable params: 12,931,390 (49.33 MB)

# %%
# Compile model
model.compile(
    optimizer=Adam(learning_rate=1e-4),  # Learning rate kecil
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# Callbacks
filepath = 'C:\\Users\\asusm\\Dropbox\\PC\\Downloads\\TA\\model\\EffNetV2B3.keras'
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, min_lr=1e-6, verbose=1)
callback_list = [checkpoint, reduce_lr]

# %%
# Melatih model dan menyimpan history
history = model.fit(
    train_generator,
    epochs=50,  # Sesuaikan jumlah epoch
    validation_data=validation_generator,
    callbacks=callback_list
)
# Out:
# Epoch 1/50
# c:\Users\asusm\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 602ms/step - accuracy: 0.0939 - loss: 3.7356
# Epoch 1: val_loss improved from inf to 2.84389, saving model to C:\Users\asusm\Dropbox\PC\Downloads\TA\model\EffNetV2B3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 38s 5s/step - accuracy: 0.0919 - loss: 3.7249 - val_accuracy: 0.1042 - val_loss: 2.8439 - learning_rate: 1.0000e-04
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 598ms/step - accuracy: 0.0889 - loss: 3.5151
# Epoch 2: val_loss improved from 2.84389 to 2.82785, saving model to C:\Users\asusm\Dropbox\PC\Downloads\TA\model\EffNetV2B3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.0876 - loss: 3.5320 - val_accuracy: 0.1028 - val_loss: 2.8278 - learning_rate: 1.0000e-04
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 596ms/step - accuracy: 0.0720 - loss: 3.7890
# Epoch 3: val_loss improved from 2.82785 to 2.81266, saving model to C:\Users\asusm\Dropbox\PC\Downloads\TA\model\EffNetV2B3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.0731 - loss: 3.7628 - val_accuracy: 0.0958 - val_loss: 2.8127 - learning_rate: 1.0000e-04
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 794ms/step - accuracy: 0.1753 - loss: 3.3304
# Epoch 4: val_loss improved from 2.81266 to 2.80073, saving model to C:\Users\asusm\Dropbox\PC\Downloads\TA\model\EffNetV2B3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 23s 4s/step - accuracy: 0.1730 - loss: 3.3230 - val_accuracy: 0.0986 - val_loss: 2.8007 - learning_rate: 1.0000e-04
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 597ms/step - accuracy: 0.1378 - loss: 3.2453
# Epoch 5: val_loss improved from 2.80073 to 2.79033, saving model to C:\Users\asusm\Dropbox\PC\Downloads\TA\model\EffNetV2B3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - accuracy: 0.1348 - loss: 3.2471 - val_accuracy: 0.1097 - val_loss: 2.7903 - learning_rate: 1.0000e-04
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 589ms/step - accuracy: 0.1096 - loss: 3.2928
# Epoch 6: val_loss improved from 2.79033 to 2.77764, saving model to C:\Users\asusm\Dropbox\PC\Downloads\TA\model\EffNetV2B3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.1150 - loss: 3.2963 - val_accuracy: 0.1111 - val_loss: 2.7776 - learning_rate: 1.0000e-04
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 712ms/step - accuracy: 0.2426 - loss: 3.1910
# Epoch 7: val_loss improved from 2.77764 to 2.76591, saving model to C:\Users\asusm\Dropbox\PC\Downloads\TA\model\EffNetV2B3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - accuracy: 0.2386 - loss: 3.1697 - val_accuracy: 0.1264 - val_loss: 2.7659 - learning_rate: 1.0000e-04
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.0972 - loss: 3.3207
# Epoch 8: val_loss improved from 2.76591 to 2.75739, saving model to C:\Users\asusm\Dropbox\PC\Downloads\TA\model\EffNetV2B3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - accuracy: 0.1061 - loss: 3.3060 - val_accuracy: 0.1208 - val_loss: 2.7574 - learning_rate: 1.0000e-04
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 595ms/step - accuracy: 0.1405 - loss: 3.1251
# Epoch 9: val_loss improved from 2.75739 to 2.74874, saving model to C:\Users\asusm\Dropbox\PC\Downloads\TA\model\EffNetV2B3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.1406 - loss: 3.1171 - val_accuracy: 0.1139 - val_loss: 2.7487 - learning_rate: 1.0000e-04
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 583ms/step - accuracy: 0.2217 - loss: 2.8769
# Epoch 10: val_loss improved from 2.74874 to 2.74009, saving model to C:\Users\asusm\Dropbox\PC\Downloads\TA\model\EffNetV2B3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.2190 - loss: 2.8691 - val_accuracy: 0.1111 - val_loss: 2.7401 - learning_rate: 1.0000e-04
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 590ms/step - accuracy: 0.2126 - loss: 2.9773
# Epoch 11: val_loss improved from 2.74009 to 2.73040, saving model to C:\Users\asusm\Dropbox\PC\Downloads\TA\model\EffNetV2B3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - accuracy: 0.2094 - loss: 2.9796 - val_accuracy: 0.1069 - val_loss: 2.7304 - learning_rate: 1.0000e-04
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 716ms/step - accuracy: 0.2494 - loss: 2.9702
# Epoch 12: val_loss improved from 2.73040 to 2.72280, saving model to C:\Users\asusm\Dropbox\PC\Downloads\TA\model\EffNetV2B3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.2506 - loss: 2.9521 - val_accuracy: 0.1028 - val_loss: 2.7228 - learning_rate: 1.0000e-04
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 585ms/step - accuracy: 0.1989 - loss: 2.8356
# Epoch 13: val_loss improved from 2.72280 to 2.71303, saving model to C:\Users\asusm\Dropbox\PC\Downloads\TA\model\EffNetV2B3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - accuracy: 0.2012 - loss: 2.8394 - val_accuracy: 0.1097 - val_loss: 2.7130 - learning_rate: 1.0000e-04
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 595ms/step - accuracy: 0.2038 - loss: 2.9398
# Epoch 14: val_loss improved from 2.71303 to 2.70319, saving model to C:\Users\asusm\Dropbox\PC\Downloads\TA\model\EffNetV2B3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - accuracy: 0.2036 - loss: 2.9281 - val_accuracy: 0.1056 - val_loss: 2.7032 - learning_rate: 1.0000e-04
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 594ms/step - accuracy: 0.2121 - loss: 2.9058
# Epoch 15: val_loss improved from 2.70319 to 2.69447, saving model to C:\Users\asusm\Dropbox\PC\Downloads\TA\model\EffNetV2B3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - accuracy: 0.2151 - loss: 2.8942 - val_accuracy: 0.1083 - val_loss: 2.6945 - learning_rate: 1.0000e-04
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 589ms/step - accuracy: 0.2933 - loss: 2.6131
# Epoch 16: val_loss improved from 2.69447 to 2.68845, saving model to C:\Users\asusm\Dropbox\PC\Downloads\TA\model\EffNetV2B3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 23s 4s/step - accuracy: 0.2900 - loss: 2.6317 - val_accuracy: 0.1097 - val_loss: 2.6885 - learning_rate: 1.0000e-04
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 633ms/step - accuracy: 0.2296 - loss: 2.6966
# Epoch 17: val_loss improved from 2.68845 to 2.68202, saving model to C:\Users\asusm\Dropbox\PC\Downloads\TA\model\EffNetV2B3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - accuracy: 0.2362 - loss: 2.6932 - val_accuracy: 0.1139 - val_loss: 2.6820 - learning_rate: 1.0000e-04
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 593ms/step - accuracy: 0.2599 - loss: 2.6450
# Epoch 18: val_loss improved from 2.68202 to 2.67469, saving model to C:\Users\asusm\Dropbox\PC\Downloads\TA\model\EffNetV2B3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - accuracy: 0.2658 - loss: 2.6417 - val_accuracy: 0.1208 - val_loss: 2.6747 - learning_rate: 1.0000e-04
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.2158 - loss: 2.7996
# Epoch 19: val_loss improved from 2.67469 to 2.66582, saving model to C:\Users\asusm\Dropbox\PC\Downloads\TA\model\EffNetV2B3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.2218 - loss: 2.7717 - val_accuracy: 0.1222 - val_loss: 2.6658 - learning_rate: 1.0000e-04
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 597ms/step - accuracy: 0.2808 - loss: 2.6916
# Epoch 20: val_loss improved from 2.66582 to 2.65797, saving model to C:\Users\asusm\Dropbox\PC\Downloads\TA\model\EffNetV2B3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - accuracy: 0.2801 - loss: 2.6860 - val_accuracy: 0.1264 - val_loss: 2.6580 - learning_rate: 1.0000e-04
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 612ms/step - accuracy: 0.2337 - loss: 2.6800
# Epoch 21: val_loss improved from 2.65797 to 2.65066, saving model to C:\Users\asusm\Dropbox\PC\Downloads\TA\model\EffNetV2B3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - accuracy: 0.2371 - loss: 2.6708 - val_accuracy: 0.1389 - val_loss: 2.6507 - learning_rate: 1.0000e-04
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 743ms/step - accuracy: 0.2021 - loss: 2.4663
# Epoch 22: val_loss improved from 2.65066 to 2.64309, saving model to C:\Users\asusm\Dropbox\PC\Downloads\TA\model\EffNetV2B3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - accuracy: 0.2153 - loss: 2.4659 - val_accuracy: 0.1458 - val_loss: 2.6431 - learning_rate: 1.0000e-04
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 585ms/step - accuracy: 0.3361 - loss: 2.7245
# Epoch 23: val_loss improved from 2.64309 to 2.63824, saving model to C:\Users\asusm\Dropbox\PC\Downloads\TA\model\EffNetV2B3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.3337 - loss: 2.7215 - val_accuracy: 0.1514 - val_loss: 2.6382 - learning_rate: 1.0000e-04
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 602ms/step - accuracy: 0.2853 - loss: 2.5138
# Epoch 24: val_loss improved from 2.63824 to 2.63287, saving model to C:\Users\asusm\Dropbox\PC\Downloads\TA\model\EffNetV2B3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.2866 - loss: 2.5040 - val_accuracy: 0.1542 - val_loss: 2.6329 - learning_rate: 1.0000e-04
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 593ms/step - accuracy: 0.3345 - loss: 2.4085
# Epoch 25: val_loss improved from 2.63287 to 2.63179, saving model to C:\Users\asusm\Dropbox\PC\Downloads\TA\model\EffNetV2B3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.3270 - loss: 2.4162 - val_accuracy: 0.1528 - val_loss: 2.6318 - learning_rate: 1.0000e-04
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 592ms/step - accuracy: 0.2385 - loss: 2.5821
# Epoch 26: val_loss improved from 2.63179 to 2.62388, saving model to C:\Users\asusm\Dropbox\PC\Downloads\TA\model\EffNetV2B3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.2430 - loss: 2.5644 - val_accuracy: 0.1583 - val_loss: 2.6239 - learning_rate: 1.0000e-04
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 599ms/step - accuracy: 0.3124 - loss: 2.5836
# Epoch 27: val_loss improved from 2.62388 to 2.61507, saving model to C:\Users\asusm\Dropbox\PC\Downloads\TA\model\EffNetV2B3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.3160 - loss: 2.5771 - val_accuracy: 0.1583 - val_loss: 2.6151 - learning_rate: 1.0000e-04
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 605ms/step - accuracy: 0.3474 - loss: 2.4864
# Epoch 28: val_loss improved from 2.61507 to 2.61126, saving model to C:\Users\asusm\Dropbox\PC\Downloads\TA\model\EffNetV2B3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - accuracy: 0.3495 - loss: 2.4724 - val_accuracy: 0.1542 - val_loss: 2.6113 - learning_rate: 1.0000e-04
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 592ms/step - accuracy: 0.3164 - loss: 2.3584
# Epoch 29: val_loss improved from 2.61126 to 2.61013, saving model to C:\Users\asusm\Dropbox\PC\Downloads\TA\model\EffNetV2B3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - accuracy: 0.3132 - loss: 2.3636 - val_accuracy: 0.1556 - val_loss: 2.6101 - learning_rate: 1.0000e-04
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 609ms/step - accuracy: 0.3367 - loss: 2.3387
# Epoch 30: val_loss did not improve from 2.61013
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.3281 - loss: 2.3525 - val_accuracy: 0.1528 - val_loss: 2.6132 - learning_rate: 1.0000e-04
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 589ms/step - accuracy: 0.3976 - loss: 2.1893
# Epoch 31: val_loss did not improve from 2.61013
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.3908 - loss: 2.2081 - val_accuracy: 0.1542 - val_loss: 2.6135 - learning_rate: 1.0000e-04
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 594ms/step - accuracy: 0.3582 - loss: 2.2320
# Epoch 32: val_loss improved from 2.61013 to 2.60791, saving model to C:\Users\asusm\Dropbox\PC\Downloads\TA\model\EffNetV2B3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.3561 - loss: 2.2375 - val_accuracy: 0.1653 - val_loss: 2.6079 - learning_rate: 1.0000e-04
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 599ms/step - accuracy: 0.3078 - loss: 2.2935
# Epoch 33: val_loss improved from 2.60791 to 2.60516, saving model to C:\Users\asusm\Dropbox\PC\Downloads\TA\model\EffNetV2B3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.3085 - loss: 2.2858 - val_accuracy: 0.1639 - val_loss: 2.6052 - learning_rate: 1.0000e-04
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 601ms/step - accuracy: 0.2923 - loss: 2.4031
# Epoch 34: val_loss improved from 2.60516 to 2.60093, saving model to C:\Users\asusm\Dropbox\PC\Downloads\TA\model\EffNetV2B3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - accuracy: 0.2961 - loss: 2.3952 - val_accuracy: 0.1639 - val_loss: 2.6009 - learning_rate: 1.0000e-04
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 613ms/step - accuracy: 0.3618 - loss: 2.2377
# Epoch 35: val_loss did not improve from 2.60093
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.3653 - loss: 2.2282 - val_accuracy: 0.1653 - val_loss: 2.6020 - learning_rate: 1.0000e-04
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 598ms/step - accuracy: 0.3655 - loss: 2.2211
# Epoch 36: val_loss did not improve from 2.60093
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.3685 - loss: 2.2283 - val_accuracy: 0.1722 - val_loss: 2.6022 - learning_rate: 1.0000e-04
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 594ms/step - accuracy: 0.3429 - loss: 2.1860
# Epoch 37: val_loss improved from 2.60093 to 2.60063, saving model to C:\Users\asusm\Dropbox\PC\Downloads\TA\model\EffNetV2B3.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.3404 - loss: 2.2116 - val_accuracy: 0.1806 - val_loss: 2.6006 - learning_rate: 1.0000e-04
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 597ms/step - accuracy: 0.3719 - loss: 2.2635
# Epoch 38: val_loss did not improve from 2.60063
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.3731 - loss: 2.2618 - val_accuracy: 0.1861 - val_loss: 2.6040 - learning_rate: 1.0000e-04
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 593ms/step - accuracy: 0.3658 - loss: 2.4110
# Epoch 39: val_loss did not improve from 2.60063
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.3678 - loss: 2.3988 - val_accuracy: 0.1972 - val_loss: 2.6050 - learning_rate: 1.0000e-04
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 593ms/step - accuracy: 0.3809 - loss: 2.2286
# Epoch 40: val_loss did not improve from 2.60063
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.3799 - loss: 2.2325 - val_accuracy: 0.2056 - val_loss: 2.6035 - learning_rate: 1.0000e-04
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 609ms/step - accuracy: 0.3250 - loss: 2.4971
# Epoch 41: val_loss did not improve from 2.60063
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.3241 - loss: 2.4928 - val_accuracy: 0.2069 - val_loss: 2.6063 - learning_rate: 1.0000e-05
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 742ms/step - accuracy: 0.4603 - loss: 2.1530
# Epoch 42: val_loss did not improve from 2.60063
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.4445 - loss: 2.1848 - val_accuracy: 0.2125 - val_loss: 2.6071 - learning_rate: 1.0000e-05
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 600ms/step - accuracy: 0.3383 - loss: 2.3271
# Epoch 43: val_loss did not improve from 2.60063
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 1e-06.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.3426 - loss: 2.3245 - val_accuracy: 0.2181 - val_loss: 2.6066 - learning_rate: 1.0000e-05
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 609ms/step - accuracy: 0.4504 - loss: 2.1321
# Epoch 44: val_loss did not improve from 2.60063
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.4492 - loss: 2.1273 - val_accuracy: 0.2194 - val_loss: 2.6087 - learning_rate: 1.0000e-06
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 607ms/step - accuracy: 0.3440 - loss: 2.3065
# Epoch 45: val_loss did not improve from 2.60063
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.3449 - loss: 2.3017 - val_accuracy: 0.2139 - val_loss: 2.6104 - learning_rate: 1.0000e-06
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 619ms/step - accuracy: 0.3348 - loss: 2.2651
# Epoch 46: val_loss did not improve from 2.60063
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.3413 - loss: 2.2526 - val_accuracy: 0.2167 - val_loss: 2.6138 - learning_rate: 1.0000e-06
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 603ms/step - accuracy: 0.4099 - loss: 2.2432
# Epoch 47: val_loss did not improve from 2.60063
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.4118 - loss: 2.2481 - val_accuracy: 0.2181 - val_loss: 2.6175 - learning_rate: 1.0000e-06
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 598ms/step - accuracy: 0.3109 - loss: 2.3204
# Epoch 48: val_loss did not improve from 2.60063
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.3103 - loss: 2.3142 - val_accuracy: 0.2236 - val_loss: 2.6219 - learning_rate: 1.0000e-06
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 593ms/step - accuracy: 0.4147 - loss: 2.2629
# Epoch 49: val_loss did not improve from 2.60063
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.4071 - loss: 2.2768 - val_accuracy: 0.2236 - val_loss: 2.6273 - learning_rate: 1.0000e-06
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 602ms/step - accuracy: 0.4667 - loss: 2.1852
# Epoch 50: val_loss did not improve from 2.60063
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 0.4614 - loss: 2.1973 - val_accuracy: 0.2208 - val_loss: 2.6302 - learning_rate: 1.0000e-06

# %%
# Plotting accuracy and loss side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 6))

# Plotting accuracy
ax1.plot(history.history['accuracy'], label='Train Accuracy')
ax1.plot(history.history['val_accuracy'], label='Validation Accuracy')
ax1.set_title('EfficientNetV2B3 Model Accuracy')
ax1.set_ylabel('Accuracy')
ax1.set_xlabel('Epoch')
ax1.legend(loc='upper left')
ax1.grid(True)

# Plotting loss
ax2.plot(history.history['loss'], label='Train Loss')
ax2.plot(history.history['val_loss'], label='Validation Loss')
ax2.set_title('EfficientNetV2B3 Model Loss')
ax2.set_ylabel('Loss')
ax2.set_xlabel('Epoch')
ax2.legend(loc='upper left')
ax2.grid(True)

plt.show()

# %%
# Path ke model yang disimpan
model_path = 'C:\\Users\\asusm\\Dropbox\\PC\\Downloads\\TA\\model\\EffNetV2B3.keras'

# Memuat model
model = load_model(model_path)

# Path ke direktori dataset
test_dir = "C:\\Users\\asusm\\Dropbox\\PC\\Downloads\\TA\\Split\\uji"

# Membuat objek ImageDataGenerator untuk data uji
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
# test_datagen = ImageDataGenerator(rescale=1.0/255)


# Load data uji
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False  # Pastikan shuffle dinonaktifkan untuk menjaga urutan data
)

# Evaluasi model pada data uji
loss, accuracy = model.evaluate(test_generator)

# Selesai menghitung waktu
end_time = time.perf_counter()

print(f"Loss: {loss}")
print(f"Accuracy: {accuracy}")

# Menghitung prediksi untuk data uji
y_pred_prob = model.predict(test_generator)
y_pred = np.argmax(y_pred_prob, axis=1)

# Mendapatkan label sebenarnya dari test_generator
y_true = test_generator.classes

# Mendapatkan label class dari test_generator
class_labels = list(test_generator.class_indices.keys())

# Menghitung metrik menggunakan sklearn
accuracy_sklearn = accuracy_score(y_true, y_pred)
precision_sklearn = precision_score(y_true, y_pred, average='weighted')
recall_sklearn = recall_score(y_true, y_pred, average='weighted')
f1_sklearn = f1_score(y_true, y_pred, average='weighted')

print("\nMetrics using sklearn:")
print(f"Accuracy: {accuracy_sklearn}")
print(f"Precision: {precision_sklearn}")
print(f"Recall: {recall_sklearn}")
print(f"F1 Score: {f1_sklearn}")

# Classification Report
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_labels))

# Confusion Matrix
conf_matrix = confusion_matrix(y_true, y_pred)

# Visualisasi Confusion Matrix
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Found 360 images belonging to 12 classes.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 14s 718ms/step - accuracy: 0.1452 - loss: 2.5815
# Loss: 2.5592234134674072
# Accuracy: 0.20555555820465088
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 13s 908ms/step
#
# Metrics using sklearn:
# Accuracy: 0.20555555555555555
# Precision: 0.33223691023745633
# Recall: 0.20555555555555555
# F1 Score: 0.18016628893295134
#
# Classification Report:
#                            precision    recall  f1-score   support
#
#  Acute & Chronic Rhinitis       0.75      0.10      0.18        30
# Acute & Chronic Sinusitis       0.05      0.10      0.07        30
#       Adenoid Hypertrophy       0.12      0.10      0.11        30
#         Allergic Rhinitis       1.00      0.07      0.12        30
#          Cavum Nasi Tumor       0.06      0.13      0.08        30
#                    Concha       0.08      0.03      0.05        30
#           Fallopian Tubes       0.25      0.07      0.11        30
#                    Normal       0.51      0.63      0.57        30
#        Normal Nasofarings       0.60      0.10      0.17        30
#                    Polyps       0.34      0.93      0.50        30
#          Septum Deviation       0.21      0.20      0.21        30
#                      Snot       0.00      0.00      0.00        30
#
#                  accuracy                           0.21       360
#                 macro avg       0.33      0.21      0.18       360
#              weighted avg       0.33      0.21      0.18       360
